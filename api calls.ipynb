# %%
data = sc.jsonFile('/data/raw/kafka/nginx.shopify/2014/10/05/*.gz').filter(lambda r: r['user_id']=="0").take(10000)
import pandas as pd

df = pd.DataFrame(data)
# Out:
# 29/10/14 20:10:57 INFO Starscream.Stardate.Sparkcontextproxy Loading from expanded path /data/raw/kafka/nginx.shopify/2014/10/05/*.gz with minsplits 0
# INFO:Starscream.Stardate.Sparkcontextproxy:Loading from expanded path /data/raw/kafka/nginx.shopify/2014/10/05/*.gz with minsplits 0

# %%
df.shape
# Out:
# (10000, 41)

# %%
puts = df['request'].map(lambda r: 'PUT' in r)

# %%
df.ix[puts]
# Out:
#     api_client_id api_permission_id app_name                 args body_bytes  \
# 19         124968           7911101  shopify                    -        495
# 27         176537           4417901  shopify                    -        524
# 28          32262            513922  shopify                    -       1712
# 36         151675           5704921  shopify                    -       1653
# 37         124968           7911101  shopify                    -        497
# 41         163647           3703391  shopify                    -       1093
# 49         124968           7911101  shopify                    -        499
# 56         132018           2354288  shopify                    -        521
# 61         221405           7000297  shopify                    -        323
# 65         259529           7550513  shopify                    -       2917
# 67         124968           8279809  shopify                    -        561
# ...

# %%
print s.
# Out:
# URI
# /admin/products/353362303/images/825165067.json         1
# /admin/products/353362535/images/825941863.json         1
# /admin/products/353362657/metafields.json               1
# /admin/products/353363085/metafields.json               1
# /admin/products/353363119/images/825166895.json         1
# /admin/products/353363335/images/825167291.json         1
# /admin/products/353363663/images/825928223.json         1
# /admin/products/353363831/images/825168451.json         1
# /admin/products/353364087/images/826003035.json         1
# /admin/products/353364123/images/825979723.json         1
# /admin/products/353364123/images/825991563.json         1
# /admin/products/353364567/images/825938051.json         1
# /admin/products/353384605/metafields/1389351865.json    1
# /admin/products/353384605/metafields/1389351877.json    1
# /admin/products/353384605/metafields/1389351881.json    1
# ...
# /admin/products/353832143/metafields.json    1
# ...

# %%
df.columns
# Out:
# Killing SparkContext <SparkContextProxy: IPython Notebook, 1800 seconds old, 80 cores> after timeout.
# Index([u'api_client_id', u'api_permission_id', u'app_name', u'args', u'body_bytes', u'client_ip', u'client_request_group_id', u'content_type', u'dest_host', u'do_not_track', u'event_dvc', u'event_id', u'event_partition_key', u'event_scope', u'event_timestamp', u'gzip_ratio', u'host_forwarded_for', u'method', u'processing_time', u'protocol', u'referer', u'remote_user', u'request', u'request_id', u'scheme', u'scheme_forwarded', u'shard_id', u'shop_id', u'stats_unique_token', u'stats_visit_token', u'status', u'upstream', u'upstream_event_id', u'upstream_processing_time', u'upstream_x_cache', u'upstream_x_runtime', u'uri', u'user_agent', u'user_id', u'user_is_admin', u'validation_errors'], dtype='object')

# %%
redshift_query("""SELECT * FAEOMFewaf WE:F"""")
